# %% [markdown]
# # Description
# Welcome to Prostate cANcer graDe Assessment (PANDA) Challenge. The task of this competition is classification of images with cancer tissue. The main challenge of this task is dealing with images of extremely high resolution and large areas of empty space. So, effective locating the areas of concern and zooming them in would be the key to reach high LB score.
#
# In this competition I found a number of public kernels performing straightforward rescaling the input images to square. However, for this particular data such an approach is not very efficient because the aspect ratio and size of provided images are not consistent and vary in a wide range. As a result, the input images are deformed to large extend in a not consistent manner uppon rescaling that limits the ability of the model to learn. Moreover, the input consists of large empty areas leading to inefficient use of GPU memory and GPU time.
#
# In this kernel I propose an alternative approach based on **Concatenate Tile pooling**. Instead of passing an entire image as an input, N tiles are selected from each image based on the number of tissue pixels (see [this kernel](https://www.kaggle.com/iafoss/panda-16x128x128-tiles) for description of data preparation and the [corresponding dataset](https://www.kaggle.com/iafoss/panda-16x128x128-tiles-data)) and passed independently through the convolutional part. The outputs of the convolutional part is concatenated in a large single map for each image preceding pooling and FC head (see image below). Since any spatial information is eliminated by the pooling layer, the Concat Tile pooling approach is nearly identical to passing an entire image through the convolutional part, excluding predictions for nearly empty regions, which do not contribute to the final prediction, and shuffle the remaining outputs into a square map of smaller size. Below I provide just a basic kernel only illustrating this approach. In my first trial I got 0.76 LB score, top 2 at the moment, and I believe it could be easily boosted to 0.80+. I hope you would enjoy my kernel, and please also check my submission kernel implementing the tile based approach.
#
# ![](https://i.ibb.co/hF6LRVm/TILE.png)

# %%
# !pip install --upgrade wandb
# !wandb login 6ff8d5e5bd920e68d1f76b574f1880278b4ac8d2

# %%
# import wandb
# from wandb.fastai import WandbCallback
# wandb.init(project="panda-competition")

# %%
# !pip3 install efficientnet_pytorch
from efficientnet_pytorch import EfficientNet
# Out:
# Requirement already satisfied: efficientnet_pytorch in /usr/local/lib/python3.6/dist-packages (0.6.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from efficientnet_pytorch) (1.5.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch->efficientnet_pytorch) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->efficientnet_pytorch) (0.16.0)

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from efficientnet_pytorch import EfficientNet

import fastai
from fastai.vision import *
from fastai.callbacks import *
import os
#from sklearn.model_selection import KFold
from radam import *
from csvlogger import *
from mish_activation import *
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import cohen_kappa_score,confusion_matrix
import warnings
warnings.filterwarnings("ignore")

fastai.__version__
# Out:
# '1.0.61'

# %%
sz = 128
bs = 32
nfolds = 4
SEED = 2020
N = 12 #number of tiles per image
TRAIN = '/content/clouderizer/panda/data/train/'
LABELS = '/content/clouderizer/panda/data/train.csv'

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True

seed_everything(SEED)

# %% [markdown]
# # Data

# %% [markdown]
# Use stratified KFold split.

# %%
df = pd.read_csv(LABELS).set_index('image_id')
files = sorted(set([p[:32] for p in os.listdir(TRAIN)]))
df = df.loc[files]
df = df.reset_index()
splits = StratifiedKFold(n_splits=nfolds, random_state=SEED, shuffle=True)
splits = list(splits.split(df,df.isup_grade))
folds_splits = np.zeros(len(df)).astype(np.int)
for i in range(nfolds): folds_splits[splits[i][1]] = i
df['split'] = folds_splits
df.head()
# Out:
#                            image_id data_provider  ...  gleason_score split
# 0  0005f7aaab2800f6170c399693a96917    karolinska  ...            0+0     0
# 1  000920ad0b612851f8e01bcc880d9b3d    karolinska  ...            0+0     1
# 2  0018ae58b01bdadc8e347995b69f99aa       radboud  ...            4+4     0
# 3  001c62abd11fa4b57bf7a6c603a11bb9    karolinska  ...            4+4     0
# 4  001d865e65ef5d2579c190a0e0350d8f    karolinska  ...            0+0     1
#
# [5 rows x 5 columns]

# %% [markdown]
# Check [this kernel](https://www.kaggle.com/iafoss/panda-16x128x128-tiles) for image stats. Since I use zero padding and background corresponds to 255, I invert images as 255-img when load them. Therefore, the mean value is computed as '1 - val'.

# %%
mean = torch.tensor([1.0-0.90949707, 1.0-0.8188697, 1.0-0.87795304])
std = torch.tensor([0.36357649, 0.49984502, 0.40477625])

# %% [markdown]
# The code below (in the hidden cell) creates ImageItemList capable of loading multiple tiles of an image. It is specific for fast.ai, and pure Pytorch code would be much simpler.

# %%
def open_image(fn:PathOrStr, div:bool=True, convert_mode:str='RGB', cls:type=Image,
        after_open:Callable=None)->Image:
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", UserWarning) # EXIF warning from TiffPlugin
        x = PIL.Image.open(fn).convert(convert_mode)
    if after_open: x = after_open(x)
    x = pil2tensor(x,np.float32)
    if div: x.div_(255)
    return cls(1.0-x) #invert image for zero padding

class MImage(ItemBase):
    def __init__(self, imgs):
        self.obj, self.data = \
          (imgs), [(imgs[i].data - mean[...,None,None])/std[...,None,None] for i in range(len(imgs))]
    
    def apply_tfms(self, tfms,*args, **kwargs):
        for i in range(len(self.obj)):
            self.obj[i] = self.obj[i].apply_tfms(tfms, *args, **kwargs)
            self.data[i] = (self.obj[i].data - mean[...,None,None])/std[...,None,None]
        return self
    
    def __repr__(self): return f'{self.__class__.__name__} {img.shape for img in self.obj}'
    def to_one(self):
        img = torch.stack(self.data,1)
        img = img.view(3,-1,N,sz,sz).permute(0,1,3,2,4).contiguous().view(3,-1,sz*N)
        return Image(1.0 - (mean[...,None,None]+img*std[...,None,None]))

class MImageItemList(ImageList):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
    
    def __len__(self)->int: return len(self.items) or 1 
    
    def get(self, i):
        fn = Path(self.items[i])
        fnames = [Path(str(fn)+'_'+str(i)+'.png')for i in range(N)]
        imgs = [open_image(fname, convert_mode=self.convert_mode, after_open=self.after_open)
               for fname in fnames]
        return MImage(imgs)

    def reconstruct(self, t):
        return MImage([mean[...,None,None]+_t*std[...,None,None] for _t in t])
    
    def show_xys(self, xs, ys, figsize:Tuple[int,int]=(300,50), **kwargs):
        rows = min(len(xs),8)
        fig, axs = plt.subplots(rows,1,figsize=figsize)
        for i, ax in enumerate(axs.flatten() if rows > 1 else [axs]):
            xs[i].to_one().show(ax=ax, y=ys[i], **kwargs)
        plt.tight_layout()
        

#collate function to combine multiple images into one tensor
def MImage_collate(batch:ItemsList)->Tensor:
    result = torch.utils.data.dataloader.default_collate(to_data(batch))
    if isinstance(result[0],list):
        result = [torch.stack(result[0],1),result[1]]
    return result

# %%
def get_data(fold=0):
    return (MImageItemList.from_df(df, path='/', folder=TRAIN, cols='image_id')
      .split_by_idx(df.index[df.split == fold].tolist())
      .label_from_df(cols=['isup_grade'])
      .transform(get_transforms(flip_vert=True,max_rotate=15),size=sz,padding_mode='zeros')
      .databunch(bs=bs,num_workers=4))

data = get_data(0)
data.show_batch()

# %% [markdown]
# # Model

# %% [markdown]
# The code below implements Concat Tile pooling idea. As a backbone I use [Semi-Weakly Supervised ImageNet pretrained ResNeXt50 model](https://github.com/facebookresearch/semi-supervised-ImageNet1K-models), which worked for me quite well in a number of previous competitions.

# %%
class Model(nn.Module):
    def __init__(self, arch='efficientnet-b0', n=6, pre=True):
        super().__init__()
        #m = EfficientNet.from_pretrained(arch)
        #self.enc = nn.Sequential(*list(m.children())[:-2])
        self.enc = EfficientNet.from_pretrained(arch)
        nc = self.enc._fc.in_features
        self.head = nn.Sequential(AdaptiveConcatPool2d(),Flatten(),nn.Linear(2*nc,512),
                      Mish(),nn.BatchNorm1d(512), nn.Dropout(0.5),nn.Linear(512,n))    
        
    def forward(self, *x):
        shape = x[0].shape
        n = len(x)
        x = torch.stack(x,1).view(-1,shape[1],shape[2],shape[3])
        #x: bs*N x 3 x 128 x 128
        x = self.enc.extract_features(x)
        #x: bs*N x C x 4 x 4
        shape = x.shape
        #concatenate the output for tiles into a single map
        x = x.view(-1,n,shape[1],shape[2],shape[3]).permute(0,2,1,3,4).contiguous()\
          .view(-1,shape[1],shape[2]*n,shape[3])
        #x: bs x C x N*4 x 4
        x = self.head(x)
        #x: bs x n
        return x

# %%
# class Model(nn.Module):
#     def __init__(self, arch='resnext50_32x4d_ssl', n=6, pre=True):
#         super().__init__()
#         m = torch.hub.load('facebookresearch/semi-supervised-ImageNet1K-models', arch)
#         self.enc = nn.Sequential(*list(m.children())[:-2])       
#         nc = list(m.children())[-1].in_features
#         self.head = nn.Sequential(AdaptiveConcatPool2d(),Flatten(),nn.Linear(2*nc,512),
#                             Mish(),nn.BatchNorm1d(512), nn.Dropout(0.5),nn.Linear(512,n))
        
#     def forward(self, *x):
#         shape = x[0].shape
#         n = len(x)
#         x = torch.stack(x,1).view(-1,shape[1],shape[2],shape[3])
#         #x: bs*N x 3 x 128 x 128
#         x = self.enc(x)
#         #x: bs*N x C x 4 x 4
#         shape = x.shape
#         #concatenate the output for tiles into a single map
#         x = x.view(-1,n,shape[1],shape[2],shape[3]).permute(0,2,1,3,4).contiguous()\
#           .view(-1,shape[1],shape[2]*n,shape[3])
#         #x: bs x C x N*4 x 4
#         x = self.head(x)
#         #x: bs x n
#         return x

# %% [markdown]
# # Training

# %%
fname = 'EFFB0'
pred,target = [],[]

for fold in range(nfolds):
    data = get_data(fold)
    model = Model()
    learn = Learner(data, model, loss_func=nn.CrossEntropyLoss(), opt_func=Over9000, 
                metrics=[KappaScore(weights='quadratic')]).to_fp16()
    logger = CSVLogger(learn, f'log_{fname}_{fold}')
    learn.clip_grad = 1.0
    learn.split([model.head])
    learn.unfreeze()
    learn.model_dir = Path("/content/clouderizer/panda/out")
    learn.load(f'{fname}_{fold}')

    learn.fit_one_cycle(16, max_lr=1e-3, div_factor=100, pct_start=0,
      callbacks = [SaveModelCallback(learn,name=f'{fname}_{fold}',monitor='kappa_score'), 
                   EarlyStoppingCallback])
    learn.load(f'{fname}_{fold}')
    torch.save(learn.model.state_dict(), f'/content/clouderizer/panda/out/{fname}_{fold}.pth')
    
    learn.model.eval()
    with torch.no_grad():
        for step, (x, y) in progress_bar(enumerate(data.dl(DatasetType.Valid)),
                                     total=len(data.dl(DatasetType.Valid))):
            p = learn.model(*x)
            pred.append(p.float().cpu())
            target.append(y.cpu())
# Out:
# Loaded pretrained weights for efficientnet-b0
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>kappa_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.856525</td>
#       <td>1.697901</td>
#       <td>0.382988</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.658494</td>
#       <td>1.654373</td>
#       <td>0.453423</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.483181</td>
#       <td>1.530050</td>
#       <td>0.546277</td>
#       <td>04:29</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.360916</td>
#       <td>1.452875</td>
#       <td>0.606649</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.297603</td>
#       <td>1.357585</td>
#       <td>0.633627</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.220870</td>
#       <td>1.383610</td>
#       <td>0.647377</td>
#       <td>04:32</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.197619</td>
#       <td>1.207204</td>
#       <td>0.683864</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.137981</td>
#       <td>1.140205</td>
#       <td>0.707220</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.159957</td>
#       <td>1.128009</td>
#       <td>0.725147</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.111681</td>
#       <td>1.134641</td>
#       <td>0.711229</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.088013</td>
#       <td>1.185608</td>
#       <td>0.716686</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.053963</td>
#       <td>1.111524</td>
#       <td>0.728634</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.036590</td>
#       <td>1.118987</td>
#       <td>0.726573</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.004933</td>
#       <td>1.111225</td>
#       <td>0.726700</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.009238</td>
#       <td>1.140821</td>
#       <td>0.720642</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.024514</td>
#       <td>1.137969</td>
#       <td>0.724965</td>
#       <td>04:31</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with kappa_score value: 0.3829876184463501.
# Better model found at epoch 1 with kappa_score value: 0.45342302322387695.
# Better model found at epoch 2 with kappa_score value: 0.546276867389679.
# Better model found at epoch 3 with kappa_score value: 0.6066493988037109.
# Better model found at epoch 4 with kappa_score value: 0.6336274147033691.
# Better model found at epoch 5 with kappa_score value: 0.6473773717880249.
# Better model found at epoch 6 with kappa_score value: 0.6838642358779907.
# Better model found at epoch 7 with kappa_score value: 0.7072195410728455.
# Better model found at epoch 8 with kappa_score value: 0.7251471877098083.
# Better model found at epoch 11 with kappa_score value: 0.7286341190338135.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='83' class='' max='83' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [83/83 00:38<00:00]
#     </div>
# Loaded pretrained weights for efficientnet-b0
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>kappa_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.833937</td>
#       <td>1.683899</td>
#       <td>0.410687</td>
#       <td>04:32</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.635139</td>
#       <td>1.623923</td>
#       <td>0.464672</td>
#       <td>04:32</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.490736</td>
#       <td>1.657855</td>
#       <td>0.529534</td>
#       <td>04:32</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.330180</td>
#       <td>1.539186</td>
#       <td>0.526722</td>
#       <td>04:32</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.286921</td>
#       <td>1.444206</td>
#       <td>0.584625</td>
#       <td>04:32</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.253692</td>
#       <td>1.362582</td>
#       <td>0.659504</td>
#       <td>04:32</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.162790</td>
#       <td>1.268948</td>
#       <td>0.661469</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.156123</td>
#       <td>1.250521</td>
#       <td>0.691931</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.126439</td>
#       <td>1.183915</td>
#       <td>0.694063</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.107594</td>
#       <td>1.308758</td>
#       <td>0.666759</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.082371</td>
#       <td>1.133183</td>
#       <td>0.708476</td>
#       <td>04:26</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.052385</td>
#       <td>1.215755</td>
#       <td>0.695468</td>
#       <td>04:26</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.042772</td>
#       <td>1.170564</td>
#       <td>0.708754</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.026178</td>
#       <td>1.170537</td>
#       <td>0.714505</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.991832</td>
#       <td>1.184601</td>
#       <td>0.713424</td>
#       <td>04:32</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.999960</td>
#       <td>1.168630</td>
#       <td>0.714816</td>
#       <td>04:34</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with kappa_score value: 0.41068702936172485.
# Better model found at epoch 1 with kappa_score value: 0.46467238664627075.
# Better model found at epoch 2 with kappa_score value: 0.5295344591140747.
# Better model found at epoch 4 with kappa_score value: 0.5846254825592041.
# Better model found at epoch 5 with kappa_score value: 0.6595039367675781.
# Better model found at epoch 6 with kappa_score value: 0.6614689826965332.
# Better model found at epoch 7 with kappa_score value: 0.6919313669204712.
# Better model found at epoch 8 with kappa_score value: 0.6940627694129944.
# Better model found at epoch 10 with kappa_score value: 0.7084755897521973.
# Better model found at epoch 12 with kappa_score value: 0.7087538242340088.
# Better model found at epoch 13 with kappa_score value: 0.7145053148269653.
# Better model found at epoch 15 with kappa_score value: 0.7148159146308899.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='83' class='' max='83' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [83/83 00:38<00:00]
#     </div>
# Loaded pretrained weights for efficientnet-b0
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>kappa_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.846563</td>
#       <td>1.754360</td>
#       <td>0.351940</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.641481</td>
#       <td>1.654742</td>
#       <td>0.420854</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.491139</td>
#       <td>1.560365</td>
#       <td>0.553102</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.342393</td>
#       <td>1.516935</td>
#       <td>0.573531</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.286287</td>
#       <td>1.453148</td>
#       <td>0.603646</td>
#       <td>04:29</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.238395</td>
#       <td>1.365270</td>
#       <td>0.651453</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.169217</td>
#       <td>1.382610</td>
#       <td>0.664651</td>
#       <td>04:29</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.152439</td>
#       <td>1.436712</td>
#       <td>0.662914</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.115716</td>
#       <td>1.331392</td>
#       <td>0.677370</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.098177</td>
#       <td>1.331597</td>
#       <td>0.686071</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.087291</td>
#       <td>1.355730</td>
#       <td>0.681807</td>
#       <td>04:29</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.040753</td>
#       <td>1.240650</td>
#       <td>0.708450</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.002720</td>
#       <td>1.207400</td>
#       <td>0.724518</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.010762</td>
#       <td>1.209186</td>
#       <td>0.724947</td>
#       <td>04:29</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.995625</td>
#       <td>1.241380</td>
#       <td>0.721599</td>
#       <td>04:29</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.016856</td>
#       <td>1.215686</td>
#       <td>0.725083</td>
#       <td>04:30</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with kappa_score value: 0.3519400954246521.
# Better model found at epoch 1 with kappa_score value: 0.4208539128303528.
# Better model found at epoch 2 with kappa_score value: 0.5531015396118164.
# Better model found at epoch 3 with kappa_score value: 0.5735310316085815.
# Better model found at epoch 4 with kappa_score value: 0.6036460995674133.
# Better model found at epoch 5 with kappa_score value: 0.6514525413513184.
# Better model found at epoch 6 with kappa_score value: 0.6646514534950256.
# Better model found at epoch 8 with kappa_score value: 0.6773703694343567.
# Better model found at epoch 9 with kappa_score value: 0.6860705614089966.
# Better model found at epoch 11 with kappa_score value: 0.7084499597549438.
# Better model found at epoch 12 with kappa_score value: 0.7245180606842041.
# Better model found at epoch 13 with kappa_score value: 0.7249473333358765.
# Better model found at epoch 15 with kappa_score value: 0.7250831127166748.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='83' class='' max='83' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [83/83 00:37<00:00]
#     </div>
# Loaded pretrained weights for efficientnet-b0
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>kappa_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.865647</td>
#       <td>1.707225</td>
#       <td>0.394935</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.643968</td>
#       <td>1.627114</td>
#       <td>0.425746</td>
#       <td>04:32</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.476311</td>
#       <td>1.607521</td>
#       <td>0.441170</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.382103</td>
#       <td>1.362121</td>
#       <td>0.593529</td>
#       <td>04:32</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.264230</td>
#       <td>1.318885</td>
#       <td>0.648825</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.231176</td>
#       <td>1.266417</td>
#       <td>0.671721</td>
#       <td>04:29</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.192232</td>
#       <td>1.281306</td>
#       <td>0.684833</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.152381</td>
#       <td>1.187978</td>
#       <td>0.701864</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.113878</td>
#       <td>1.335687</td>
#       <td>0.672109</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.105247</td>
#       <td>1.178712</td>
#       <td>0.707119</td>
#       <td>04:38</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.084060</td>
#       <td>1.193738</td>
#       <td>0.701397</td>
#       <td>04:54</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.056160</td>
#       <td>1.229258</td>
#       <td>0.696049</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.068789</td>
#       <td>1.208492</td>
#       <td>0.710083</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.027188</td>
#       <td>1.168725</td>
#       <td>0.716711</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.987103</td>
#       <td>1.165025</td>
#       <td>0.720477</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.977623</td>
#       <td>1.177199</td>
#       <td>0.718105</td>
#       <td>04:31</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with kappa_score value: 0.3949353098869324.
# Better model found at epoch 1 with kappa_score value: 0.42574554681777954.
# Better model found at epoch 2 with kappa_score value: 0.441169798374176.
# Better model found at epoch 3 with kappa_score value: 0.5935291051864624.
# Better model found at epoch 4 with kappa_score value: 0.6488254070281982.
# Better model found at epoch 5 with kappa_score value: 0.6717211604118347.
# Better model found at epoch 6 with kappa_score value: 0.684833288192749.
# Better model found at epoch 7 with kappa_score value: 0.7018642425537109.
# Better model found at epoch 9 with kappa_score value: 0.707118809223175.
# Better model found at epoch 12 with kappa_score value: 0.7100832462310791.
# Better model found at epoch 13 with kappa_score value: 0.7167107462882996.
# Better model found at epoch 14 with kappa_score value: 0.7204772233963013.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='83' class='' max='83' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [83/83 00:37<00:00]
#     </div>

# %%
p = torch.argmax(torch.cat(pred,0),1)
t = torch.cat(target)
print(cohen_kappa_score(t,p,weights='quadratic'))
print(confusion_matrix(t,p))
# Out:
# 0.7222135977834916
# [[2590  162    2   13   73   33]
#  [ 819 1338  126   97  193   43]
#  [ 170  395  233  231  222   90]
#  [ 124   96   44  267  433  262]
#  [ 155   73   18   74  622  303]
#  [ 135   11   11   24  232  802]]

# %%
fname = 'EFFB0'
pred,target = [],[]

for fold in range(nfolds):
    data = get_data(fold)
    model = Model()
    learn = Learner(data, model, loss_func=nn.CrossEntropyLoss(), opt_func=Over9000, 
                metrics=[KappaScore(weights='quadratic')]).to_fp16()
    logger = CSVLogger(learn, f'log_{fname}_{fold}')
    learn.clip_grad = 1.0
    learn.split([model.head])
    learn.unfreeze()
    learn.model_dir = Path("/content/clouderizer/panda/out")
    learn.load(f'{fname}_{fold}')

    learn.fit_one_cycle(16, max_lr=1e-3, div_factor=100, pct_start=0,
      callbacks = [SaveModelCallback(learn,name=f'{fname}_{fold}',monitor='kappa_score'), 
                   EarlyStoppingCallback(learn, monitor='valid_loss', patience=3)])
    learn.load(f'{fname}_{fold}')
    torch.save(learn.model.state_dict(), f'/content/clouderizer/panda/out/{fname}_{fold}.pth')
    
    learn.model.eval()
    with torch.no_grad():
        for step, (x, y) in progress_bar(enumerate(data.dl(DatasetType.Valid)),
                                     total=len(data.dl(DatasetType.Valid))):
            p = learn.model(*x)
            pred.append(p.float().cpu())
            target.append(y.cpu())
# Out:
# Loaded pretrained weights for efficientnet-b0
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>kappa_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.077272</td>
#       <td>1.148993</td>
#       <td>0.728921</td>
#       <td>04:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.029840</td>
#       <td>1.131574</td>
#       <td>0.731077</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.052177</td>
#       <td>1.138292</td>
#       <td>0.727653</td>
#       <td>04:32</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.009080</td>
#       <td>1.143089</td>
#       <td>0.723089</td>
#       <td>04:32</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.016257</td>
#       <td>1.270039</td>
#       <td>0.702992</td>
#       <td>04:32</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.982097</td>
#       <td>1.109975</td>
#       <td>0.720764</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.959227</td>
#       <td>1.108419</td>
#       <td>0.743140</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.936280</td>
#       <td>1.080442</td>
#       <td>0.752879</td>
#       <td>04:32</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.904634</td>
#       <td>1.063642</td>
#       <td>0.747059</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.873756</td>
#       <td>1.123455</td>
#       <td>0.729757</td>
#       <td>04:29</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.830777</td>
#       <td>1.056708</td>
#       <td>0.756578</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.848031</td>
#       <td>1.070526</td>
#       <td>0.737286</td>
#       <td>04:28</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.795549</td>
#       <td>1.100709</td>
#       <td>0.750896</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.790269</td>
#       <td>1.083125</td>
#       <td>0.748751</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.815237</td>
#       <td>1.085260</td>
#       <td>0.746886</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.784194</td>
#       <td>1.090894</td>
#       <td>0.746769</td>
#       <td>04:31</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with kappa_score value: 0.7289207577705383.
# Better model found at epoch 1 with kappa_score value: 0.7310773134231567.
# Better model found at epoch 6 with kappa_score value: 0.7431395053863525.
# Better model found at epoch 7 with kappa_score value: 0.75287926197052.
# Better model found at epoch 10 with kappa_score value: 0.7565775513648987.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='83' class='' max='83' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [83/83 00:37<00:00]
#     </div>
# Loaded pretrained weights for efficientnet-b0
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>kappa_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.032013</td>
#       <td>1.102463</td>
#       <td>0.724928</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.016099</td>
#       <td>1.121062</td>
#       <td>0.727446</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.049376</td>
#       <td>1.162252</td>
#       <td>0.742699</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.002003</td>
#       <td>1.165721</td>
#       <td>0.726179</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.018046</td>
#       <td>1.213314</td>
#       <td>0.703744</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.980488</td>
#       <td>1.111364</td>
#       <td>0.711392</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.928335</td>
#       <td>1.169989</td>
#       <td>0.733962</td>
#       <td>04:26</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.914734</td>
#       <td>1.228869</td>
#       <td>0.729604</td>
#       <td>04:26</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.897795</td>
#       <td>1.090841</td>
#       <td>0.745141</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.854753</td>
#       <td>1.102163</td>
#       <td>0.745396</td>
#       <td>04:22</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.821557</td>
#       <td>1.157260</td>
#       <td>0.742373</td>
#       <td>04:21</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.801268</td>
#       <td>1.099128</td>
#       <td>0.754887</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.755395</td>
#       <td>1.113019</td>
#       <td>0.753062</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.764354</td>
#       <td>1.136940</td>
#       <td>0.745931</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.746811</td>
#       <td>1.127823</td>
#       <td>0.746651</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.744517</td>
#       <td>1.141388</td>
#       <td>0.744753</td>
#       <td>04:25</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with kappa_score value: 0.7249283790588379.
# Better model found at epoch 1 with kappa_score value: 0.7274458408355713.
# Better model found at epoch 2 with kappa_score value: 0.742699146270752.
# Better model found at epoch 8 with kappa_score value: 0.7451406121253967.
# Better model found at epoch 9 with kappa_score value: 0.7453956604003906.
# Better model found at epoch 11 with kappa_score value: 0.7548874616622925.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='83' class='' max='83' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [83/83 00:37<00:00]
#     </div>
# Loaded pretrained weights for efficientnet-b0
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>kappa_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.028910</td>
#       <td>1.176250</td>
#       <td>0.724697</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.020042</td>
#       <td>1.185228</td>
#       <td>0.726666</td>
#       <td>04:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.012451</td>
#       <td>1.188824</td>
#       <td>0.718785</td>
#       <td>04:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.014112</td>
#       <td>1.217313</td>
#       <td>0.716532</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.971411</td>
#       <td>1.134472</td>
#       <td>0.740807</td>
#       <td>04:26</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.967109</td>
#       <td>1.342213</td>
#       <td>0.738155</td>
#       <td>04:26</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.918875</td>
#       <td>1.266027</td>
#       <td>0.720381</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.896372</td>
#       <td>1.150478</td>
#       <td>0.746176</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.863493</td>
#       <td>1.160878</td>
#       <td>0.738720</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.843773</td>
#       <td>1.166042</td>
#       <td>0.748359</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.812606</td>
#       <td>1.180479</td>
#       <td>0.745222</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.793915</td>
#       <td>1.147650</td>
#       <td>0.759144</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.753055</td>
#       <td>1.168807</td>
#       <td>0.744508</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.756912</td>
#       <td>1.183768</td>
#       <td>0.748334</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.744446</td>
#       <td>1.181676</td>
#       <td>0.743578</td>
#       <td>04:26</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.738563</td>
#       <td>1.173016</td>
#       <td>0.746445</td>
#       <td>04:26</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with kappa_score value: 0.7246967554092407.
# Better model found at epoch 1 with kappa_score value: 0.7266659140586853.
# Better model found at epoch 4 with kappa_score value: 0.7408069372177124.
# Better model found at epoch 7 with kappa_score value: 0.7461761236190796.
# Better model found at epoch 9 with kappa_score value: 0.7483594417572021.
# Better model found at epoch 11 with kappa_score value: 0.7591440081596375.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='83' class='' max='83' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [83/83 00:37<00:00]
#     </div>
# Loaded pretrained weights for efficientnet-b0
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>kappa_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.017874</td>
#       <td>1.122637</td>
#       <td>0.732736</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.009028</td>
#       <td>1.285670</td>
#       <td>0.699300</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.038901</td>
#       <td>1.278754</td>
#       <td>0.699557</td>
#       <td>04:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.003761</td>
#       <td>1.103239</td>
#       <td>0.722071</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.022759</td>
#       <td>1.179858</td>
#       <td>0.723107</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.960251</td>
#       <td>1.236792</td>
#       <td>0.730181</td>
#       <td>04:23</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.957440</td>
#       <td>1.095008</td>
#       <td>0.746398</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.924071</td>
#       <td>1.225835</td>
#       <td>0.727659</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.871260</td>
#       <td>1.139232</td>
#       <td>0.738724</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.860435</td>
#       <td>1.116300</td>
#       <td>0.745009</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.840181</td>
#       <td>1.181936</td>
#       <td>0.735998</td>
#       <td>04:23</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.801068</td>
#       <td>1.161213</td>
#       <td>0.753668</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.778530</td>
#       <td>1.181993</td>
#       <td>0.742861</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.746329</td>
#       <td>1.144163</td>
#       <td>0.747732</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.762172</td>
#       <td>1.144732</td>
#       <td>0.752648</td>
#       <td>04:28</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.767444</td>
#       <td>1.163617</td>
#       <td>0.748147</td>
#       <td>04:24</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with kappa_score value: 0.7327362298965454.
# Better model found at epoch 6 with kappa_score value: 0.7463980913162231.
# Better model found at epoch 11 with kappa_score value: 0.753667950630188.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='83' class='' max='83' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [83/83 00:37<00:00]
#     </div>
